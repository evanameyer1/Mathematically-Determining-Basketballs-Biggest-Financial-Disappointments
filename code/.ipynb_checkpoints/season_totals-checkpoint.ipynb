# %%
import requests
from bs4 import BeautifulSoup
import uuid
import difflib
import html5lib
import time
import pandas as pd
from sqlalchemy import create_engine
import psycopg2
pd.options.mode.chained_assignment = None

# %%
player_index = pd.read_csv('../updated_datasets/player_index.csv')
player_index = player_index[player_index.columns[1:]]
player_index
# Out:
#                 player                                  uuid
# 0     Hot Rod Williams  ca94dd3e-c3dc-4682-8c88-0ed654c9d074
# 1          Danny Ferry  4d2819b0-30c9-40f3-af49-4b950b0fad78
# 2           Mark Price  1a806ca8-ea9c-4690-8fe4-0b7d13c80d36
# 3       Brad Daugherty  ae75e1f9-765b-4cde-afbc-b5e9f18e0a26
# 4          Larry Nance  97054146-250e-4988-aff6-40ce7e6f6c4d
# ...                ...                                   ...
# 2819        Vit Krejci  9b06ee3b-d2b2-4e58-9689-a11051808fde
# 2820      Olivier Sarr  d09f39f5-e68c-4f3d-ba3c-1e7946491fcd
# 2821  Lindy Waters III  a2d20bf5-1dab-4cfc-80e6-e0c848d31e9e
# 2822       Rob Edwards  f388acbe-7951-43e5-8778-dab1019c1843
# 2823    Zavier Simpson  df1508b7-0c24-4d83-bf2b-81a1ace956a7
#
# [2824 rows x 2 columns]

# %%
def season_totals(start_year, end_year):
    df_list = []
    for i in range(start_year + 1, end_year + 2):
        var_name = f'season_totals_{i - 1}'
        r = requests.get(f'https://www.basketball-reference.com/leagues/NBA_{i}_totals.html')
        if r.status_code == 200:
            soup = BeautifulSoup(r.content, 'html.parser')
            table = soup.find('table')
            test = pd.read_html(str(table))[0]
            
            #table cleaning
            test.columns = test.columns.str.lower()
            test = test[test['player'] != 'Player'].drop(columns=['rk'])
            test.fillna(0, inplace=True)
            globals()[var_name] = test.merge(player_index)
            df_list.append(globals()[var_name])
            print(f'{var_name} worked!')
            
        else:
            print(f'ERROR {r.status_code}')
        
        time.sleep(30)
        
    return df_list

# %%
df_list = season_totals(1990, 2004)
# Out:
# season_totals_1990 worked!
# season_totals_1991 worked!
# season_totals_1992 worked!
# season_totals_1993 worked!
# season_totals_1994 worked!
# season_totals_1995 worked!
# season_totals_1996 worked!
# season_totals_1997 worked!
# season_totals_1998 worked!
# season_totals_1999 worked!
# season_totals_2000 worked!
# season_totals_2001 worked!
# season_totals_2002 worked!
# season_totals_2003 worked!
# season_totals_2004 worked!

# %%
season_totals_2004
# Out:
#                   player pos age   tm   g  gs    mp   fg  fga   fg%  ...  orb  \
# 0    Shareef Abdur-Rahim  PF  28  POR  54  49  1867  337  670  .503  ...  123
# 1         Cory Alexander  SG  31  CHA  16   1   201   16   49  .327  ...    8
# 2            Malik Allen  PF  26  TOT  36   1   519   84  177  .475  ...   40
# 3            Malik Allen  PF  26  MIA  14   0   248   35   76  .461  ...   24
# 4            Malik Allen  PF  26  CHA  22   1   271   49  101  .485  ...   16
# ..                   ...  ..  ..  ...  ..  ..   ...  ...  ...   ...  ...  ...
# 504         Qyntel Woods  SF  23  MIA   3   0    40    5   12  .417  ...    2
# 505    Metta World Peace  SF  25  IND   7   7   291   59  119  .496  ...    8
# 506        Dorell Wright  SF  19  MIA   3   0    27    3   11  .273  ...    0
# 507      Lorenzen Wright   C  29  MEM  80  77  2287  320  683  .469  ...  177
# 508          Wang Zhizhi   C  27  MIA  20   0    92   17   36  .472  ...    6
#
#      drb  trb  ast stl blk  tov   pf  pts  \
# 0    269  392  111  49  26  117  150  909
# 1     21   29   37   9   1   19   29   49
# 2     59   99   18   9  22   18   53  194
# 3     28   52   11   4  11   11   29   83
# 4     31   47    7   5  11    7   24  111
# ..   ...  ...  ...  ..  ..  ...  ...  ...
# 504    4    6    0   4   0    2    6   10
# 505   37   45   22  12   6   17   27  172
# 506    1    1    3   4   0    3    2    7
# 507  436  613   87  58  69  100  251  771
# 508   12   18    5   3   2    5    9   43
#
#                                      uuid
# 0    fe3dd58a-1354-44f3-8d09-e6c39cb1cca5
# 1    aec90717-ab44-4cfe-afb6-0feb8b6f9362
# 2    6c881a9f-326a-4c7c-8b77-64040bbf30b8
# 3    6c881a9f-326a-4c7c-8b77-64040bbf30b8
# 4    6c881a9f-326a-4c7c-8b77-64040bbf30b8
# ..                                    ...
# 504  83e3a6e4-f017-458b-b7a4-f67a4e2f9912
# 505  670a19ff-960f-4b66-89c5-c438ef9dcd19
# 506  8d19fa58-5d7c-49eb-9712-a43a2d02db6d
# 507  bab51822-a357-43c7-956a-e988098dc9e7
# 508  2f0a09c5-4a53-48d5-951d-09df02d44838
#
# [509 rows x 30 columns]

# %%
df_list.extend(season_totals(2005, 2021))
# Out:
# season_totals_2005 worked!
# season_totals_2006 worked!
# season_totals_2007 worked!
# season_totals_2008 worked!
# season_totals_2009 worked!
# season_totals_2010 worked!
# season_totals_2011 worked!
# season_totals_2012 worked!
# season_totals_2013 worked!
# season_totals_2014 worked!
# season_totals_2015 worked!
# season_totals_2016 worked!
# season_totals_2017 worked!
# season_totals_2018 worked!
# season_totals_2019 worked!
# season_totals_2020 worked!
# season_totals_2021 worked!

# %%
len(df_list)
# Out:
# 32

# %%
season_totals_2004.head(15)
# Out:
#                  player    pos age   tm   g  gs    mp   fg  fga   fg%  ...  \
# 0   Shareef Abdur-Rahim     PF  28  POR  54  49  1867  337  670  .503  ...
# 1        Cory Alexander     SG  31  CHA  16   1   201   16   49  .327  ...
# 2           Malik Allen     PF  26  TOT  36   1   519   84  177  .475  ...
# 3           Malik Allen     PF  26  MIA  14   0   248   35   76  .461  ...
# 4           Malik Allen     PF  26  CHA  22   1   271   49  101  .485  ...
# 5            Tony Allen     SG  23  BOS  77  34  1262  184  387  .475  ...
# 6          Rafer Alston     PG  28  TOR  80  78  2717  403  974  .414  ...
# 7        Chris Andersen      C  26  NOH  67   2  1430  191  358  .534  ...
# 8        Derek Anderson     SG  30  POR  47  32  1239  152  391  .389  ...
# 9        Kenny Anderson     PG  34  TOT  43  20   743   85  201  .423  ...
# 10       Kenny Anderson     PG  34  ATL  39  20   717   81  190  .426  ...
# 11       Kenny Anderson     PG  34  LAC   4   0    26    4   11  .364  ...
# 12     Shandon Anderson  SF-SG  31  TOT  66   5  1171   98  217  .452  ...
# 13     Shandon Anderson     SG  31  NYK   1   0    20    0    2  .000  ...
# 14     Shandon Anderson     SF  31  MIA  65   5  1151   98  215  .456  ...
#
#     orb  drb  trb  ast  stl  blk  tov   pf   pts  \
# 0   123  269  392  111   49   26  117  150   909
# 1     8   21   29   37    9    1   19   29    49
# 2    40   59   99   18    9   22   18   53   194
# 3    24   28   52   11    4   11   11   29    83
# 4    16   31   47    7    5   11    7   24   111
# 5    85  136  221   64   76   24   77  156   492
# 6    42  237  279  514  118    7  170  212  1136
# 7   137  273  410   71   14  100   64  144   513
# 8    25  103  128  143   36    4   70   89   432
# 9    24   64   88  103   33    0   49   87   203
# 10   23   60   83   98   33    0   46   81   195
# 11    1    4    5    5    0    0    3    6     8
# 12   41  150  191   70   40   14   50  138   255
# 13    1    0    1    0    0    0    1    2     0
# 14   40  150  190   70   40   14   49  136   255
#
#                                     uuid
# 0   fe3dd58a-1354-44f3-8d09-e6c39cb1cca5
# 1   aec90717-ab44-4cfe-afb6-0feb8b6f9362
# 2   6c881a9f-326a-4c7c-8b77-64040bbf30b8
# 3   6c881a9f-326a-4c7c-8b77-64040bbf30b8
# 4   6c881a9f-326a-4c7c-8b77-64040bbf30b8
# 5   917674b3-1b6e-48ed-8d3b-f9161c1ea734
# 6   ee905b13-ef4f-4bb4-9dd7-a8bf290c289a
# 7   1c7a2c3b-e319-4c55-9294-2550d654cf28
# 8   bf77e8c7-0dcd-4d9f-b189-9d1ad588d259
# 9   a8644ea2-3e28-4207-98be-fda50363c248
# 10  a8644ea2-3e28-4207-98be-fda50363c248
# 11  a8644ea2-3e28-4207-98be-fda50363c248
# 12  40966e4d-7253-436a-a7f9-3fb958f92711
# 13  40966e4d-7253-436a-a7f9-3fb958f92711
# 14  40966e4d-7253-436a-a7f9-3fb958f92711
#
# [15 rows x 30 columns]

# %%
def count_nulls(tables):
    for table in tables:
        print(f'{sum(table.isnull().sum())} nulls')

# %%
count_nulls(df_list)
# Out:
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls
# 0 nulls

# %%
season_totals_2004[season_totals_2004['player'].duplicated()]
# Out:
#                  player pos age   tm   g  gs    mp   fg  fga   fg%  ... orb  \
# 3           Malik Allen  PF  26  MIA  14   0   248   35   76  .461  ...  24
# 4           Malik Allen  PF  26  CHA  22   1   271   49  101  .485  ...  16
# 10       Kenny Anderson  PG  34  ATL  39  20   717   81  190  .426  ...  23
# 11       Kenny Anderson  PG  34  LAC   4   0    26    4   11  .364  ...   1
# 13     Shandon Anderson  SG  31  NYK   1   0    20    0    2  .000  ...   1
# ..                  ...  ..  ..  ...  ..  ..   ...  ...  ...   ...  ...  ..
# 491      Aaron Williams   C  33  TOR  23   4   165   15   36  .417  ...  10
# 493       Eric Williams  SG  32  NJN  21  21   739   87  185  .470  ...  28
# 494       Eric Williams  SG  32  TOR  34  18   583   55  145  .379  ...  16
# 500  Corliss Williamson  PF  31  PHI  48   5  1056  194  417  .465  ...  73
# 501  Corliss Williamson  PF  31  SAC  24   4   471   79  167  .473  ...  31
#
#      drb  trb ast stl blk tov   pf  pts                                  uuid
# 3     28   52  11   4  11  11   29   83  6c881a9f-326a-4c7c-8b77-64040bbf30b8
# 4     31   47   7   5  11   7   24  111  6c881a9f-326a-4c7c-8b77-64040bbf30b8
# 10    60   83  98  33   0  46   81  195  a8644ea2-3e28-4207-98be-fda50363c248
# 11     4    5   5   0   0   3    6    8  a8644ea2-3e28-4207-98be-fda50363c248
# 13     0    1   0   0   0   1    2    0  40966e4d-7253-436a-a7f9-3fb958f92711
# ..   ...  ...  ..  ..  ..  ..  ...  ...                                   ...
# 491   19   29   2   1   3   6   45   36  f01bd8ac-7c4a-48e8-8480-b319dbe8bacd
# 493   67   95  42  16   2  34   80  265  20616e0d-ed38-4118-9459-4bd2d79e8bad
# 494   61   77  50  22   2  26   67  159  20616e0d-ed38-4118-9459-4bd2d79e8bad
# 500  105  178  43  26  12  60  144  518  54d2cdae-41c5-4f0a-82c6-1bb15dabbaf1
# 501   50   81  35  12   3  26   74  223  54d2cdae-41c5-4f0a-82c6-1bb15dabbaf1
#
# [104 rows x 30 columns]

# %%
season_totals_2004[season_totals_2004.duplicated(subset=['player'], keep='first') == False].reset_index(drop=True)
# Out:
#                   player pos age   tm   g  gs    mp   fg  fga   fg%  ...  orb  \
# 0    Shareef Abdur-Rahim  PF  28  POR  54  49  1867  337  670  .503  ...  123
# 1         Cory Alexander  SG  31  CHA  16   1   201   16   49  .327  ...    8
# 2            Malik Allen  PF  26  TOT  36   1   519   84  177  .475  ...   40
# 3             Tony Allen  SG  23  BOS  77  34  1262  184  387  .475  ...   85
# 4           Rafer Alston  PG  28  TOR  80  78  2717  403  974  .414  ...   42
# ..                   ...  ..  ..  ...  ..  ..   ...  ...  ...   ...  ...  ...
# 400         Qyntel Woods  SF  23  MIA   3   0    40    5   12  .417  ...    2
# 401    Metta World Peace  SF  25  IND   7   7   291   59  119  .496  ...    8
# 402        Dorell Wright  SF  19  MIA   3   0    27    3   11  .273  ...    0
# 403      Lorenzen Wright   C  29  MEM  80  77  2287  320  683  .469  ...  177
# 404          Wang Zhizhi   C  27  MIA  20   0    92   17   36  .472  ...    6
#
#      drb  trb  ast  stl blk  tov   pf   pts  \
# 0    269  392  111   49  26  117  150   909
# 1     21   29   37    9   1   19   29    49
# 2     59   99   18    9  22   18   53   194
# 3    136  221   64   76  24   77  156   492
# 4    237  279  514  118   7  170  212  1136
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 400    4    6    0    4   0    2    6    10
# 401   37   45   22   12   6   17   27   172
# 402    1    1    3    4   0    3    2     7
# 403  436  613   87   58  69  100  251   771
# 404   12   18    5    3   2    5    9    43
#
#                                      uuid
# 0    fe3dd58a-1354-44f3-8d09-e6c39cb1cca5
# 1    aec90717-ab44-4cfe-afb6-0feb8b6f9362
# 2    6c881a9f-326a-4c7c-8b77-64040bbf30b8
# 3    917674b3-1b6e-48ed-8d3b-f9161c1ea734
# 4    ee905b13-ef4f-4bb4-9dd7-a8bf290c289a
# ..                                    ...
# 400  83e3a6e4-f017-458b-b7a4-f67a4e2f9912
# 401  670a19ff-960f-4b66-89c5-c438ef9dcd19
# 402  8d19fa58-5d7c-49eb-9712-a43a2d02db6d
# 403  bab51822-a357-43c7-956a-e988098dc9e7
# 404  2f0a09c5-4a53-48d5-951d-09df02d44838
#
# [405 rows x 30 columns]

# %%
def remove_duplicates(tables):
    cleaned_df_list = []
    for i in range(len(tables)):
        years = [year for year in range(1990, 2022)]
        var_name = f'season_totals_{years[i]}'
        globals()[var_name] = tables[i][tables[i].duplicated(subset=['player'], keep='first') == False].reset_index(drop=True)
        cleaned_df_list.append(globals()[var_name])
        globals()[var_name].to_csv(f'../updated_datasets/season_totals/{var_name}.csv')
        print(f'{var_name} is done!')
    return cleaned_df_list

# %%
cleaned_df_list = remove_duplicates(df_list)
# Out:
# season_totals_1990 is done!
# season_totals_1991 is done!
# season_totals_1992 is done!
# season_totals_1993 is done!
# season_totals_1994 is done!
# season_totals_1995 is done!
# season_totals_1996 is done!
# season_totals_1997 is done!
# season_totals_1998 is done!
# season_totals_1999 is done!
# season_totals_2000 is done!
# season_totals_2001 is done!
# season_totals_2002 is done!
# season_totals_2003 is done!
# season_totals_2004 is done!
# season_totals_2005 is done!
# season_totals_2006 is done!
# season_totals_2007 is done!
# season_totals_2008 is done!
# season_totals_2009 is done!
# season_totals_2010 is done!
# season_totals_2011 is done!
# season_totals_2012 is done!
# season_totals_2013 is done!
# season_totals_2014 is done!
# season_totals_2015 is done!
# season_totals_2016 is done!
# season_totals_2017 is done!
# season_totals_2018 is done!
# season_totals_2019 is done!
# season_totals_2020 is done!
# season_totals_2021 is done!
